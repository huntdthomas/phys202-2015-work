# %% [markdown]
# # Theory and Practice of Visualization Exercise 1

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *positive* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [Vox](http://www.vox.com/)
# * [Upshot](http://www.nytimes.com/upshot/)
# * [538](http://fivethirtyeight.com/)
# * [BuzzFeed](http://www.buzzfeed.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
# Add your filename and uncomment the following line:
Image(filename='White_House_emissions_targets.png')

# %% [markdown]
# Describe in detail the ways in which the visualization exhibits graphical *integrity* and *excellence*:

# %% [markdown]
# It is clear from the data that we, the readers, are being shown a relation between carbon dioxide production (in millions of metric tons) and the year. Actual data is juxtaposed with projected data, nicely differentiated with solid lines and dotted lines, respectively. The U.S. target for C02 production is shown (we are well above it). Certain years are highlighted to denote an economic recession - which nicely lines up with declines in Carbon Dioxide emission.
#
# The graph clearly shows values (to appropriate scales) of carbon dioxide emission and are related to the year. The graph is properly titled, the only hand waveyness comes from the projection of CO2 emissions, which is properly explained. There is no distortion of data, unnecessary distractions, or citing of data out of context.
