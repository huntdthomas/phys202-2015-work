# %% [markdown]
# # Theory and Practice of Visualization Exercise 2

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Violations of graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *negative* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [CNN](http://www.cnn.com/)
# * [Fox News](http://www.foxnews.com/)
# * [Time](http://time.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
# Add your filename and uncomment the following line:
Image(filename='Cost of gas.jpg')

# %% [markdown]
# Describe in detail the ways in which the visualization violates graphical *integrity* and *excellence*:

# %% [markdown]
# The scale on the x-axis is completely weird. It jumps from a scale of over a year ago to a week ago. I believe it is meant to show how the cost of gas is leveling out, but obviously this would appear to happen if we show a small change (over a small time) juxtaposed with a high change (over a large time) even though the slope may have or may have not changed at all.
#
# That being said, it is not at all clear if the slope has changed or if the scale has changed
