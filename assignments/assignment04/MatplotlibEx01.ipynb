# %% [markdown]
# # Matplotlib Exercise 1

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Line plot of sunspot data

# %% [markdown]
# Download the `.txt` data for the "Yearly mean total sunspot number [1700 - now]" from the [SILSO](http://www.sidc.be/silso/datafiles) website. Upload the file to the same directory as this notebook.

# %%
import os
assert os.path.isfile('yearssn.dat')

# %% [markdown]
# Use `np.loadtxt` to read the data into a NumPy array called `data`. Then create two new 1d NumPy arrays named `years` and `ssc` that have the sequence of year and sunspot counts.

# %%
f = np.loadtxt('yearssn.dat')
data = np.array(f)
year = data[:,0]
ssc = data[:,1]
#print(data)
#print(years)
#print(ssc)

# %%
assert len(year)==315
assert year.dtype==np.dtype(float)
assert len(ssc)==315
assert ssc.dtype==np.dtype(float)

# %% [markdown]
# Make a line plot showing the sunspot count as a function of year.
#
# * Customize your plot to follow Tufte's principles of visualizations.
# * Adjust the aspect ratio/size so that the steepest slope in your plot is *approximately* 1.
# * Customize the box, grid, spines and ticks to match the requirements of this data.

# %%
plt.figure(figsize=(15,5),dpi = 1800)
plt.plot(years,ssc,'-')
plt.xlabel("Year")
plt.xlim(right=year[-1])
plt.ylabel("Sun Spot Count")
plt.title("Sun Spot Count vs. Year")

# %%
assert True # leave for grading

# %% [markdown]
# Describe the choices you have made in building this visualization and how they make it effective.

# %% [markdown]
# I titled the plot Sun Spot Count vs. Year, as it clearly describes what data I am presenting. I labelled the axes with corresponding data name. I changed the right side x limit to be equal to the last year in the data for the x axis, as there was previously unused whitespace. I saw no need to change tick marks or tick laebls. Increased the size along the x axis so the data lines didn't seem so bunched up together.

# %% [markdown]
# Now make 4 subplots, one for each century in the data set. This approach works well for this dataset as it allows you to maintain mild slopes while limiting the overall width of the visualization. Perform similar customizations as above:
#
# * Customize your plot to follow Tufte's principles of visualizations.
# * Adjust the aspect ratio/size so that the steepest slope in your plot is *approximately* 1.
# * Customize the box, grid, spines and ticks to match the requirements of this data.

# %%
plt.figure(figsize=(15,5))
plt.plot(years[0:100],ssc[0:100],'-')
plt.xlabel("Year")
plt.xlim(right=year[100])
plt.ylim(0,200)
plt.ylabel("Sun Spot Count")
plt.title("Sun Spot Count vs. Year: 1700 - 1800")

plt.figure(figsize=(15,5))
plt.plot(years[99:200],ssc[99:200],'-')
plt.xlabel("Year")
plt.xlim(year[99],year[200])
plt.ylim(0,200)
plt.ylabel("Sun Spot Count")
plt.title("Sun Spot Count vs. Year: 1800 - 1900")

plt.figure(figsize=(15,5))
plt.plot(years[199:300],ssc[199:300],'-')
plt.xlabel("Year")
plt.xlim(year[199],year[300])
plt.ylim(0,200)
plt.ylabel("Sun Spot Count")
plt.title("Sun Spot Count vs. Year: 1900 - 2000")

plt.figure(figsize=(15,5))
plt.plot(years[299:314],ssc[299:314],'-')
plt.xlabel("Year")
plt.xlim(year[299],year[314])
plt.ylim(0,200)
plt.ylabel("Sun Spot Count")
plt.title("Sun Spot Count vs. Year: 2000 - ")

# %%
assert True # leave for grading

# %% [markdown]
# In the above subplots you will notice that i changed the y limit to 200 in all the figures, even though the maximum was below that. I did this so I could keep a sense of scale between centuries.
