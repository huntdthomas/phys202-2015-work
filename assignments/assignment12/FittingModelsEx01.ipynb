# %% [markdown]
# # Fitting Models Exercise 1

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as opt

# %% [markdown]
# ## Fitting a quadratic curve

# %% [markdown]
# For this problem we are going to work with the following model:
#
# $$ y_{model}(x) = a x^2 + b x + c $$
#
# The true values of the model parameters are as follows:

# %%
a_true = 0.5
b_true = 2.0
c_true = -4.0

# %% [markdown]
# First, generate a dataset using this model using these parameters and the following characteristics:
#
# * For your $x$ data use 30 uniformly spaced points between $[-5,5]$.
# * Add a noise term to the $y$ value at each point that is drawn from a normal distribution with zero mean and standard deviation 2.0. Make sure you add a different random number to each point (see the `size` argument of `np.random.normal`).
#
# After you generate the data, make a plot of the raw data (use points).

# %%
x = np.linspace(-5,5,30)
dy = 2
ydata = a_true*x**2 + b_true*x + c_true +np.random.normal(0.0,dy,size=30)
plt.figure(figsize=(10,10))
plt.title("Quadratic Curve with Error")
plt.xlabel('x')
plt.ylabel('y')
plt.errorbar(x,ydata,dy,fmt='.k',ecolor='red')
# Out:
# <Container object of 3 artists>

# %%
assert True # leave this cell for grading the raw data generation and plot

# %% [markdown]
# Now fit the model to the dataset to recover estimates for the model's parameters:
#
# * Print out the estimates and uncertainties of each parameter.
# * Plot the raw data and best fit of the model.

# %%
def model(x,a,b,c):
    return a*x**2 + b*x + c
best,model = opt.curve_fit(model,x,ydata,sigma=dy)
print('a = {0:.3f} +/- {1:.3f}'.format(best[0],np.sqrt(model[0,0])))
print('b = {0:.3f} +/- {1:.3f}'.format(best[1],np.sqrt(model[1,1])))
print('c = {0:.3f} +/- {1:.3f}'.format(best[2],np.sqrt(model[2,2])))

xfit = np.linspace(-5,5,30)
yfit = best[0]*xfit**2 + best[1]*xfit + best[2]
plt.figure(figsize=(10,10))
plt.plot(xfit,yfit)
plt.errorbar(x,ydata,dy,fmt='.k',ecolor='red')
plt.xlabel('x')
plt.ylabel('y');
plt.title("Curve Fitted Polynomial")
# Out:
# a = 0.499 +/- 0.053
# b = 2.129 +/- 0.140
# c = -3.735 +/- 0.630

# %%
assert True # leave this cell for grading the fit; should include a plot and printout of the parameters+errors
